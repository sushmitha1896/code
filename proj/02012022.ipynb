# %%
Ref="..."

Alt="..."
 
for i in Alt:
    if (i=="A"):print(i,"T",end="")
    elif (i=="T"):print("A",end="")
    elif (i=="G"):print("C",end="")
    elif (i=="C"):print("G",end="")
# Out:
# A TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACA TCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TA TCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA TA TACGA TA TAACCCGCCA TCA TCCA TCA TCA T

# %%
reference="..."

alt="..."
 
print(" ",end="")
for i in reference:
    print(i,end=' ')
print("\n")

if(len(reference)==len(alt)):
    for i in range(0,len(reference)):
        if(reference[i]=="A"):
            print('\033[1;31m',"T",end='')
        elif(reference[i]=="C"):
            print('\033[1;31m',"G",end='')
        elif(reference[i]=="G"):
            print('\033[1;31m',"C",end='')
        elif(reference[i]=="T"):
            print('\033[0;30m',"A",end='')
else:
    print("There is an error")
# Out:
#  A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A
# ...

# %%
reference="..."

alt="..."
 
print(" ",end="")
for i in reference:
    print(i,end=' ')
print("\n")

if(len(reference)==len(alt)):
    for i in range(0,len(reference)):
        if(reference[i]=="A"):
            print('\033[1;31m',i,"T",end='')
        elif(reference[i]=="C"):
            print('\033[1;31m',i,"G",end='')
        elif(reference[i]=="G"):
            print('\033[1;31m',i,"C",end='')
        elif(reference[i]=="T"):
            print('\033[0;30m',i,"A",end='')
else:
    print("There is an error")
# Out:
#  A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A
# ...

# %%
Ref="..."
print('\033[1;31;43m')
Alt="..."

#print('\033[1;31;43m')
#print('\033[1;31;43m')
if(len(Ref)==len(Alt)):
    for i in range(0,len(Ref),10):
        if(Ref[i]!=Alt[i]):
            print("at base",i,Ref[i],Alt[i],sep="\t",end="\n")
# Out:
# at base	10	T	G
# at base	20	T	A
