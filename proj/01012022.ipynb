# %%
Ref="..."

Alt="..."

#if len(ref)!=len(alt):
    #print("error")
#for i in range(0,len(ref)+1):
    #ref[i]==alt(i)
if(len(Ref)!=len(Alt)):
    print("Error")

for i in range(0,len(Ref)+1):
    if(Ref[i] != Alt[i]):
        print("There is an alteration at",i,"From",Ref[i],"To",Alt[i])
# Out:
# There is an alteration at 77 From G To A
# There is an alteration at 383 From A To G
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10972/3824845513.py in <module>
#      11
#      12 for i in range(0,len(Ref)+1):
# ---> 13     if(Ref[i] != Alt[i]):
#      14         print("There is an alteration at",i,"From",Ref[i],"To",Alt[i])
#      15
#
# IndexError: string index out of range

# %%
Ref="..."
print('\033[1;31;43m')
Alt="..."

#print('\033[1;31;43m')
print('\033[1;31;43m')
if(len(Ref)==len(Alt)):
    for i in range(0,len(Ref)):
        if(Ref[i]!=Alt[i]):
            print("There is an alteration at the base",i,"From",Ref[i],"To",Alt[i],sep="\t",end="\n")
        else:
            continue
else:
    print("There is an error")
# Out:
# There is an alteration at the base	41	From	G	To	A
# There is an alteration at the base	77	From	G	To	A
# There is an alteration at the base	383	From	A	To	G

# %%
Ref="..."

Alt="..."

print(" ",end="")
for i in Ref:
    print(i,end=' ')
print("\n")

if(len(Ref)==len(Alt)):
    for i in range(0,len(Ref)):
        if(Ref[i]!=Alt[i]):
            print('\033[1;31m',Alt[i],end='')
        else:
            print('\033[0;30m',Alt[i],end='')
else:
    print("There is an error")
# Out:
#  A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A A T G C A A N N N N T T G G G G G A G A G G A G A G A A T G C A A N N N N T T G G G C G G A G A G G A G A G A
# ...

# %%
reference="ATGC"
alt="GTGT"
print(" ",end="")
for i in reference:
    print(i,end=' ')
print("\n")

if(len(reference)==len(alt)):
    for i in range(0,len(reference)):
        if(reference[i]!=alt[i]):
            print('\033[1;31m',alt[i],end='')
        else:
            print('\033[0;30m',alt[i],end='')
else:
    print("There is an error")
# Out:
#  A T G C
#
#  G T G T

# %%
Ref="..."

Alt="..."
 
for i in Alt:
    if (i=="A"):print("T",end="")
    elif (i=="T"):print("A",end="")
    elif (i=="G"):print("C",end="")
    elif (i=="C"):print("G",end="")
# Out:
# ...
